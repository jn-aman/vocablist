# %%
import pandas as pd
file_name="vocab.xlsx"
xl_file = pd.ExcelFile(file_name)


data = pd.read_excel(file_name, sheet_name='Sheet1')
# dat.dropna(subset=[col_list])  # col_list is a list of column names to consider for nan values.

# %%
data.head()
# Out:
#   Birth n death  Body n disease-1 Body n disease-2 Beautiful mind-1  \
# 0    Primordial  Corp-body (root)           Sloven    Cog-knowledge
# 1       Genesis            Corpse        Sloth (n)       Cognizance
# 2     Procreate         Corporeal   Slothful (adj)        Cognition
# 3         Spawn       Incorporeal           Supine  cognitive (adj)
# 4      Engender            Corpus            Slack        Incognito
#
#   Beautiful mind-2                Shabd -1              Shabd -2  \
# 0              Ken  Loq/loc/log-words,talk  Voke/voc-call, bring
# 1            Edify              Lex- words            Vociferous
# 2         Tutelage              Verb- word                Invoke
# 3          Diffuse                Prologue                 Evoke
# 4          Suffuse                Epilogue               Conjure
#
#             Religion            Rajneeti -1    Rajneeti-2  ...  \
# 0          Omni- all  Archy/cracy-rule/govt  Crede- trust  ...
# ...

# %%
data
# Out:
#       Birth n death   Body n disease-1  Body n disease-2 Beautiful mind-1  \
# 0        Primordial   Corp-body (root)            Sloven    Cog-knowledge
# 1           Genesis             Corpse         Sloth (n)       Cognizance
# 2         Procreate          Corporeal    Slothful (adj)        Cognition
# 3             Spawn        Incorporeal            Supine  cognitive (adj)
# 4          Engender             Corpus             Slack        Incognito
# 5             Beget              Canon         Somnolent  Terra incognito
# 6      Prolific - 1             Oeuvre         Sedentary   Gnos-knowledge
# 7         Fecund -2          Corpulent         Recumbent         Agnostic
# 8           Progeny             Rotund            Torpid        Prognosis
# 9           Lineage              Stout           Dormant        Diagnosis
# 10         Pedigree             Portly         Lassitude    Prognosticate
# 11          Kindred              Plump  Langor (languid)      Soothsaying
# ...

# %%
p={'Birth n death': {0: 'Primordial', 1: 'Genesis', 2: 'Procreate', 3: 'Spawn', 4: 'Engender', 5: 'Beget', 6: 'Prolific - 1', 7: 'Fecund -2', 8: 'Progeny', 9: 'Lineage', 10: 'Pedigree', 11: 'Kindred', 12: 'Genealogy', 13: 'Generic', 14: 'Genocide', 15: 'Viv-Life', 16: 'Vivify', 17: 'Vivacious', 18: 'Vivisection', 19: 'Nascent', 20: 'Embryonic', 21: 'Germinal', 22: 'Rudimentary', 23: 'Inchoate', 24: 'Incipient', 25: 'Precocious - 1', 26: 'Prodigy -2', 27: 'Ephemeral', 28: 'Evanescent', 29: 'Deciduous', 30: 'Fugitive', 31: 'Transient', 32: 'Temporal', 33: 'Fleeting', 34: 'Morph- form', 35: 'Metamorphosis', 36: 'Amorphous', 37: 'Morphology', 38: 'Mor/mort/necr-death', 39: 'Mortify', 40: 'Moribund', 41: 'Morbid', 42: 'Morose', 43: 'Mortician', 44: 'Inter', 45: 'Exhume (opposite)', 46: 'Sepulcher', 47: 'Necropolis', 48: 'Wraith', 49: 'Spectre', 50: 'Apparition', 51: 'Necromancy', 52: 'Clairvoyance', 53: 'Exorcise', 54: 'Moratorium', 55: 'Annihilate', 56: 'Raze', 57: 'Obliterate', 58: 'Exterminate', 59: 'Ravage', 60: 'Decimate', 61: 'Apocalypse', 62: 'Armagaddon', 63: 'Catastrophe', 64: 'Utopia', 65: 'Ethereal', 66: 'Elysian', 67: 'Empyreal', 68: 'Stygian', 69: 'Infernal', 70: 'Diabolical', 71: 'Fiendish', 72: 'Purgatory'}, 'Body n disease-1': {0: 'Corp-body (root)', 1: 'Corpse', 2: 'Corporeal', 3: 'Incorporeal', 4: 'Corpus', 5: 'Canon', 6: 'Oeuvre', 7: 'Corpulent', 8: 'Rotund', 9: 'Stout', 10: 'Portly', 11: 'Plump', 12: 'Brawny', 13: 'Sinewy', 14: 'Soma-body (root)', 15: 'Somatic', 16: 'Psychosomatic', 17: 'Carn-flesh (root)', 18: 'Carnivores', 19: 'Carnal', 20: 'Carnage', 21: 'Sanguinary', 22: 'Gory', 23: 'Sangu-blood(root)', 24: 'Sanguine', 25: 'Consanguinity', 26: 'Sangfroid', 27: 'Equanimity', 28: 'Animated', 29: 'Unanimous', 30: 'Magnanimous', 31: 'Puillanimous', 32: 'Capit-head (root)', 33: 'Decapitate', 34: 'Recapitulate', 35: 'Manu-hand (root)', 36: 'Manuscript', 37: 'Manacle', 38: 'Fetters', 39: 'Manumit (opposite)', 40: 'Emancipate', 41: 'Visage', 42: 'Physionomy', 43: 'Countenance', 44: 'Oss -bone (root)', 45: 'Osseous', 46: 'Ossify', 47: 'Gorge-throat (root)', 48: 'Disgorge', 49: 'gorge on', 50: 'Gustatory', 51: 'Olfactory', 52: 'Tactile', 53: 'Aural', 54: 'Visible', 55: 'Visceral', 56: 'Viscera', 57: 'Supple', 58: 'lithe', 59: 'limber', 60: 'agile', 61: 'celerous (celerity)', 62: 'Spry', 63: 'Nimble'}, 'Body n disease-2': {0: 'Sloven', 1: 'Sloth (n)', 2: 'Slothful (adj)', 3: 'Supine', 4: 'Slack', 5: 'Somnolent', 6: 'Sedentary', 7: 'Recumbent', 8: 'Torpid', 9: 'Dormant', 10: 'Lassitude', 11: 'Langor (languid)', 12: 'Listless', 13: 'Lackadaisical', 14: 'Indolent', 15: 'Vegetated', 16: 'Comatose', 17: 'Malaise', 18: 'Queasy', 19: 'Squeamish', 20: 'Bilious', 21: 'Dyspeptic', 22: 'Giddy-dizzy', 23: 'Vertigo', 24: 'Pallid', 25: 'Palor (extra)', 26: 'Ashen', 27: 'Sallow (extra)', 28: 'Wan', 29: 'Blanched', 30: 'Gaunt', 31: 'Groggy', 32: 'Cadaverous', 33: 'Debilitated', 34: 'Enervated', 35: 'Etiolated', 36: 'Haggard', 37: 'Frail', 38: 'Senile', 39: 'Atrophy', 40: 'Anorexia', 41: 'Amnesia', 42: 'Innocuous', 43: 'Virulent (opposite)', 44: 'Noxious', 45: 'Pernicious', 46: 'Insidious', 47: 'Detrimental', 48: 'Deleterious', 49: 'Pestilential', 50: 'Malignant', 51: 'Malevolent', 52: 'Baneful', 53: 'Baleful', 54: 'Blight', 55: 'Canker', 56: 'Quack', 57: 'Charlatan', 58: 'Mountebank', 59: 'Phoney', 60: 'Prophylactic', 61: 'Opiate', 62: 'Sedative', 63: 'Anaesthetic', 64: 'Soporific', 65: 'Tranquilizer', 66: 'Purgative', 67: 'Placebo', 68: 'Panacea', 69: 'Nostrum', 70: 'Euthanasia'}, 'Beautiful mind-1': {0: 'Cog-knowledge', 1: 'Cognizance', 2: 'Cognition', 3: 'cognitive (adj)', 4: 'Incognito', 5: 'Terra incognito', 6: 'Gnos-knowledge', 7: 'Agnostic', 8: 'Prognosis', 9: 'Diagnosis', 10: 'Prognosticate', 11: 'Soothsaying', 12: 'Augury', 13: 'Prophesy', 14: 'portent', 15: 'premonition', 16: 'foreboding', 17: 'Soph-wisdom', 18: 'sophomoric', 19: 'Sophistry', 20: 'Ratiocinate', 21: 'Cogitate', 22: 'Muse over', 23: 'Mull over', 24: 'Ruminate', 25: 'Cerebrate', 26: 'Contemplate', 27: 'Deliberate', 28: 'Cogent', 29: 'Forceful', 30: 'Compelling', 31: 'Well-founded', 32: 'Tenable', 33: 'Plausible', 34: 'Dialectical', 35: 'Polemical', 36: 'Tendentious', 37: 'germane', 38: 'befitting', 39: 'pertinent', 40: 'apropos', 41: 'apposite', 42: 'buttress', 43: 'corroborate', 44: 'substantiate', 45: 'shore up', 46: 'underpin', 47: 'assent', 48: 'concede', 49: 'accede', 50: 'imprimatur', 51: 'acquiesce', 52: 'countenance', 53: 'accord', 54: 'Ratify', 55: 'extraneous', 56: 'tangential', 57: 'impertinent', 58: 'inadmissible', 59: 'refute', 60: 'repudiate', 61: 'rebut', 62: 'remonstrate', 63: 'expostulate', 64: 'countermand', 65: 'discount', 66: 'debunk', 67: 'belie', 68: 'gainsay'}, 'Beautiful mind-2': {0: 'Ken', 1: 'Edify', 2: 'Tutelage', 3: 'Diffuse', 4: 'Suffuse', 5: 'Apprise', 6: 'Desseminate', 7: 'Ped-child (root)', 8: 'Pedophile', 9: 'Paediatrician', 10: 'Pedagogy', 11: 'Pedant', 12: 'Rote', 13: 'Discourse', 14: 'Assimilate', 15: 'Comprehend', 16: 'Apprehend', 17: 'Ingest', 18: 'Fathom', 19: 'Discern', 20: 'Imbibe', 21: 'Construe', 22: 'Plumb', 23: 'Minutiae', 24: 'Subtleties', 25: 'Nunances', 26: 'Niceties', 27: 'Acumen', 28: 'Sapient', 29: 'Sagacious', 30: 'Perspicacious', 31: 'Canny', 32: 'Insightful', 33: 'Ingenious', 34: 'Astute', 35: 'Savant', 36: 'Erudite', 37: 'Idiot savant', 38: 'Idiosyncrasy', 39: 'Eccentricity', 40: 'Quirk', 41: 'Nonconformist', 42: 'Maverik', 43: 'Bohemian', 44: 'Stupified', 45: 'Flummox', 46: 'Fluster', 47: 'Baffle', 48: 'Bemuse', 49: 'Bewilder', 50: 'Bamboozle', 51: 'Addle', 52: 'Muddle', 53: 'Befuddle', 54: 'Discombobulate', 55: 'Disconcert', 56: 'Discomfit', 57: 'Flabbergast', 58: 'Perplex', 59: 'Nonplus', 60: 'Confound', 61: 'Delirium', 62: 'Hysteria', 63: 'Botch up', 64: 'Bungle up', 65: 'Garble', 66: 'Obfuscate', 67: 'Quandary', 68: 'Vacillate', 69: 'Dither', 70: 'Ambivalence', 71: 'Conundrum', 72: 'Waver'}, 'Shabd -1': {0: 'Loq/loc/log-words,talk', 1: 'Lex- words', 2: 'Verb- word', 3: 'Prologue', 4: 'Epilogue', 5: 'Somniloquent', 6: 'Soliloquy', 7: 'Loquacious', 8: 'Garrulous', 9: 'Prolix', 10: 'Voluble', 11: 'Verbiage', 12: 'Verbose', 13: 'Expatiate', 14: 'Harp', 15: 'Rave & rant', 16: 'Chatter', 17: 'Gibber', 18: 'Jabber', 19: 'Prate', 20: 'Prattle', 21: 'Patter', 22: 'Natter', 23: 'Blather', 24: 'Blabber', 25: 'Babble', 26: 'Palaver', 27: 'Drivel', 28: 'Waffle', 29: 'Tautology', 30: 'Redundancy', 31: 'Pleonasm', 32: 'Superfluity', 33: 'Abridge', 34: 'Truncate', 35: 'Excise', 36: 'Expurgate', 37: 'Bowdlerize', 38: 'Concise', 39: 'Succinct', 40: 'Terse', 41: 'Brusque', 42: 'Brevity', 43: 'Pithy', 44: 'Tac/tic- silent', 45: 'Tacit', 46: 'Taciturn', 47: 'Reticent', 48: 'Laconic', 49: 'Coy', 50: 'Demure', 51: 'Sententious', 52: 'Sententia', 53: 'Aphorism', 54: 'Apothegm', 55: 'Adage', 56: 'Epigram', 57: 'Maxim', 58: 'Axiom', 59: 'Saw', 60: 'Dictum', 61: 'Eloquent', 62: 'Glib', 63: 'Rhetoric', 64: 'Facile', 65: 'Pompous', 66: 'Florid', 67: 'Grandiloquent', 68: 'Bombastic', 69: 'Declamatory', 70: 'Braggadocio', 71: 'Braggart', 72: 'Blowhard', 73: 'Magniloquent', 74: 'Bumptious', 75: 'Tumid', 76: 'Turgid', 77: 'Overwrought', 78: 'Pontificating', 79: 'Hyperbole-1', 80: 'Romance-2', 81: 'Felicity', 82: 'Kitsch (opposite)', 83: 'Plagiarism', 84: 'Verbatim'}, 'Shabd -2': {0: 'Voke/voc-call, bring', 1: 'Vociferous', 2: 'Invoke', 3: 'Evoke', 4: 'Conjure', 5: 'Revoke', 6: 'Irrevocable', 7: 'Convoke', 8: 'Equivocal', 9: 'Circumlocution', 10: 'Circuitous', 11: 'Tortuous', 12: 'Rambling', 13: 'Meandering', 14: 'Deviating', 15: 'Digressive', 16: 'Desultory', 17: 'Discursive', 18: 'Serpentine', 19: 'Sinuous', 20: 'Abstruse', 21: 'Arcane', 22: 'Obscure', 23: 'Mystified', 24: 'Rarefied', 25: 'Recondite', 26: 'Occult', 27: 'Uncanny', 28: 'Esoteric', 29: 'Evasive', 30: 'Elusive', 31: 'Enigmatic', 32: 'Parlance', 33: 'argot', 34: 'jargon', 35: 'jive', 36: 'vernacular', 37: 'dialect', 38: 'patois', 39: 'lingo', 40: 'slang', 41: 'colloquial', 42: 'Allusion', 43: 'innuendo', 44: 'insinuation', 45: 'Pheme-say(root)', 46: 'Euphemism', 47: 'blasphemy', 48: 'dict-say (root)', 49: 'malediction', 50: 'benediction', 51: 'dictum', 52: 'decree', 53: 'diktat', 54: 'edict', 55: 'interdict', 56: 'enjoinment', 57: 'injunction', 58: 'fiat', 59: 'proscription', 60: 'scrib/scrip-write', 61: 'circumscribe', 62: 'transcribe', 63: 'lexicon', 64: 'compendium', 65: 'dossier', 66: 'dissertation', 67: 'treatise', 68: 'addendum', 69: 'annals', 70: 'anecdote', 71: 'lore', 72: 'Euphony', 73: 'mellifluous', 74: 'sonorous', 75: 'dulcet', 76: 'Cacophony', 77: 'gruff', 78: 'raspy', 79: 'strident', 80: 'jarring', 81: 'stentorian', 82: 'trenchant', 83: 'Enunciate', 84: 'articulate'}, 'Religion': {0: 'Omni- all', 1: 'Omnipresent', 2: 'Omnipotent', 3: 'Omniscient', 4: 'Sacr/secr- sacred', 5: 'Sacrosanct', 6: 'Inviolable (syn)', 7: 'Reverential', 8: 'Deference', 9: 'Venerable', 10: 'Hoary', 11: 'Sacrilege', 12: 'Blas phemy', 13: 'Profanity', 14: 'Defile', 15: 'Desecration', 16: 'Consecration (opp)', 17: 'Theo-god/religion', 18: 'Theist', 19: 'Atheist', 20: 'Theology', 21: 'Theocracy', 22: 'Anathema', 23: 'Apotheosis (1)', 24: 'Beatify', 25: 'Canonize', 26: 'Deify', 27: 'Idolize', 28: 'Apotheosis (2)', 29: 'Paragon', 30: 'Paradigm', 31: 'Prototype', 32: 'Archetype', 33: 'Quientessence', 34: 'Personification', 35: 'Epitome', 36: 'Canon', 37: 'Dogma', 38: 'Doctrine', 39: 'Commandments', 40: 'Credo', 41: 'Precepts', 42: 'Tenets', 43: 'Cant', 44: 'Sanctimonious-1', 45: 'Pharisaical-2', 46: 'Ascetic', 47: 'Celibate', 48: 'Eremetic', 49: 'Hermit', 50: 'Anchorite', 51: 'Puritan', 52: 'Recluse', 53: 'Debauched', 54: 'Depraved', 55: 'Debased', 56: 'Perverted', 57: 'Sleazy', 58: 'Seamy', 59: 'Sordid', 60: 'Squalid', 61: 'Seedy', 62: 'Reprobate', 63: 'Rakish', 64: 'Unwholesome'}, 'Rajneeti -1': {0: 'Archy/cracy-rule/govt', 1: 'Monarchy', 2: 'Democracy', 3: 'Patriarchy', 4: 'Anarchy', 5: 'Oligarchy', 6: 'Nepotism/cronytism', 7: 'Coterie', 8: 'Cabal', 9: 'Theocracy', 10: 'Plutocracy', 11: 'Gerontocracy', 12: 'Autocracy', 13: 'Hegemony', 14: 'Dema/demo-people', 15: 'Democracy', 16: 'Suffrage', 17: 'Enfranchise', 18: 'Plebiscite', 19: 'Denizens', 20: 'Hoi polloi', 21: 'Horde', 22: 'Demography', 23: 'Demagogue', 24: 'Rabble rouser', 25: 'Incendiary', 26: 'Firebrand', 27: 'Reactionary', 28: 'Ombudsman', 29: 'Jurisprudence', 30: 'Propriety', 31: 'Probity', 32: 'Rectitude', 33: 'Uprightness', 34: 'Righteousness', 35: 'Scrupulosity', 36: 'Seemliness', 37: 'Decorum', 38: 'Punctiliousness', 39: 'Utopia', 40: 'Egalitarian', 41: 'Evenhanded', 42: 'Iniquitous', 43: 'Invidious', 44: 'Proselytize', 45: 'Apostate', 46: 'Renegade', 47: 'Defector', 48: 'Turncoat', 49: 'Quisling', 50: 'Traitor', 51: 'Poltroon', 52: 'Recreant', 53: 'Expatriate', 54: 'Forsake', 55: 'Abdicate', 56: 'Abnegate', 57: 'Abjure', 58: 'Renounce', 59: 'Relinquish', 60: 'Volte-face', 61: 'Allegiance (opposite)', 62: 'Steadfastness', 63: 'Staunch', 64: 'Stalwart', 65: 'Titular', 66: 'Quorum'}, 'Rajneeti-2': {0: 'Crede- trust', 1: 'credence', 2: 'credibility', 3: 'incredulous', 4: 'credulous', 5: 'incredible', 6: 'Veri- truth', 7: 'Veracity', 8: 'mendacity (opp)', 9: 'Veritable', 10: 'Aver', 11: 'Prevaricate', 12: 'Equivocation', 13: 'Parry', 14: 'Hedge', 15: 'Evasion', 16: 'Mince', 17: 'Oblique', 18: 'Candid', 19: 'Forthright', 20: 'Audacious', 21: 'Affront', 22: 'Insolent', 23: 'Impudent', 24: 'Brassy', 25: 'Blatant', 26: 'Brazen', 27: 'Barefaced', 28: 'Temerity', 29: 'Presumptuous', 30: 'Limpid', 31: 'Lucid', 32: 'Pellucid', 33: 'Conspicuous', 34: 'Palpable', 35: 'ostensible', 36: 'manifest', 37: 'Turbid', 38: 'Murky', 39: 'Nebulous', 40: 'Menda- error', 41: 'Mendacity', 42: 'Emend', 43: 'Make amends', 44: 'Fallible', 45: 'Anomaly', 46: 'errant', 47: 'erroneous', 48: 'aberration', 49: 'disabuse', 50: 'Chicanery', 51: 'Plot', 52: 'Scheme', 53: 'Strategm', 54: 'gambit', 55: 'devious', 56: 'artifice', 57: 'wily ', 58: 'turpitude', 59: 'vice', 60: 'deceit', 61: 'guile', 62: 'hoodwink', 63: 'delude', 64: 'machination', 65: 'contrivance', 66: 'nefariousness', 67: 'knavishness', 68: 'Jaunt', 69: 'junket', 70: 'contingent', 71: 'emissary', 72: 'exigency', 73: 'expediency', 74: 'Debacle', 75: 'Fiasco'}, 'Office office-1': {0: 'Incumbent', 1: 'Anoint', 2: 'Echelon', 3: 'Nonentity', 4: 'Nondescript', 5: 'Obeisance', 6: 'Servitude/servile', 7: 'Obsequious', 8: 'sychophantic', 9: 'kowtow', 10: 'grovel', 11: 'toady', 12: 'flattering', 13: 'cajole', 14: 'coax', 15: 'truckle', 16: 'fawn', 17: 'bootlicking', 18: 'blandish', 19: 'wheedle', 20: 'inveigle', 21: 'ingratiate', 22: 'unctuous', 23: 'earthy', 24: 'self-effacing', 25: 'self-condescending', 26: 'self-deprecating', 27: 'retiring', 28: 'unassuming', 29: 'meticulous', 30: 'scruplous', 31: 'painstaking', 32: 'exacting', 33: 'demanding', 34: 'punctilious', 35: 'fussy', 36: 'finicky', 37: 'fastidious', 38: 'decorous', 39: 'diligent', 40: 'assiduous', 41: 'sedulous', 42: 'industrious', 43: 'arduous', 44: 'laborious', 45: 'strenuous', 46: 'herculean', 47: 'perseverant', 48: 'toilsome', 49: 'peruse', 50: 'neophyte', 51: 'novice', 52: 'callow', 53: 'verdant', 54: 'rookie', 55: 'greenhorn', 56: 'puerile', 57: 'tyro', 58: 'fledgling', 59: 'newbie', 60: 'dilettente', 61: 'sophomore', 62: 'botch up', 63: 'protégé', 64: 'naïve', 65: 'artless', 66: 'ingenuous', 67: 'guileless', 68: 'gullible', 69: 'credulous', 70: 'childlike', 71: 'oaf', 72: 'buffon', 73: 'dolt', 74: 'numbskull', 75: 'nincompoop', 76: 'nitwit', 77: 'simpleton', 78: 'blockhead', 79: 'inane', 80: 'imbecile', 81: 'vacuous', 82: 'fatuous', 83: 'asinine', 84: 'daft', 85: 'dunce', 86: 'moron'}, 'Office office-2': {0: 'Officious', 1: 'prying', 2: 'meddlesome', 3: 'officious (2)', 4: 'peremptory', 5: 'overbearing', 6: 'imperious', 7: 'despotic', 8: 'tyranncial', 9: 'obtrusive', 10: 'presumptuous', 11: 'autocratic', 12: 'foist', 13: 'stickler', 14: 'martinet', 15: 'egotism', 16: 'conceit', 17: 'supercillious', 18: 'smug', 19: 'vain/vanity', 20: 'vainglorious', 21: 'hubris', 22: 'haughty', 23: 'overweening', 24: 'narcisstic', 25: 'megalomania', 26: 'disdain', 27: 'contempt', 28: 'scorn', 29: 'snub', 30: 'slight', 31: 'condescend', 32: 'deign', 33: 'patronize', 34: 'belittle', 35: 'derogatory', 36: 'pejorative', 37: 'disparaging', 38: 'Perfunctory', 39: 'superficial', 40: 'cursory', 41: 'slapdash', 42: 'shoddy', 43: 'cavalier', 44: 'remiss', 45: 'offhand', 46: 'flippant', 47: 'frivolous', 48: 'malingerer', 49: 'sinecure', 50: 'oust', 51: 'drudgery', 52: 'tedious/tedium', 53: 'onerous/onus', 54: 'dexterous', 55: 'adroit', 56: 'adept', 57: 'deft', 58: 'virtuoso', 59: 'aesthete', 60: 'maestro', 61: 'finesse', 62: 'prowess', 63: 'artiste', 64: 'consummate', 65: 'versed', 66: 'proficient', 67: 'luminary', 68: 'flair', 69: 'knack', 70: 'non paraeil', 71: 'Forte', 72: 'Repertoire', 73: 'Hone', 74: 'whet'}, 'Money matters': {0: 'Lucre/pecun -money', 1: 'Lucrative (adj)', 2: 'Avarice', 3: 'Cupidity', 4: 'Rapacity', 5: 'Hireling', 6: 'Mercenary', 7: 'Pittance', 8: 'Pecuniary', 9: 'Impecuniousness (opp)', 10: 'Penury', 11: 'Privation', 12: 'Pauperism', 13: 'Want', 14: 'Indigence', 15: 'Destitution', 16: 'Ragamuffin', 17: 'Urchin', 18: 'Waif', 19: 'Vagabond', 20: 'Vagrant', 21: 'Proletarian', 22: 'Eke out a living', 23: 'Windfall', 24: 'Fortuitous', 25: 'Serendipitous', 26: 'Gratis', 27: 'Bourgeois', 28: 'Affluence', 29: 'Opulence', 30: 'Mogul', 31: 'Tycoon', 32: 'Baron', 33: 'Personage', 34: 'Magnate', 35: 'Hedonist', 36: 'Sybarite', 37: 'Indulgent', 38: 'Squander', 39: 'Fritter away', 40: 'Trifle away', 41: 'Splurge', 42: 'Spendthrift', 43: 'Prodigal', 44: 'Profligate', 45: 'Extravagant', 46: 'Frugal', 47: 'Provident', 48: 'Prudent', 49: 'Thrifty', 50: 'Husbanding', 51: 'Skinflint', 52: 'Tightwad', 53: 'Tightfisted', 54: 'Parsimonious', 55: 'Stingy', 56: 'Mingy', 57: 'Niggard', 58: 'Penny-pinching', 59: 'Philanthropic', 60: 'Benevolent', 61: 'Beneficent', 62: 'Munificent', 63: 'Magnanimous', 64: 'Generous', 65: 'Largesse', 66: 'Altruism', 67: 'Dupe', 68: 'Mulct', 69: 'Bilk', 70: 'Con', 71: 'Swindle', 72: 'Chisel', 73: 'Cozen', 74: 'Fleece', 75: 'Hoodwink', 76: 'Mug'}, 'Size matters': {0: 'Iota', 1: 'Dab', 2: 'Jot', 3: 'Vestige', 4: 'Scintilla', 5: 'Modicum', 6: 'Puny', 7: 'Wee', 8: 'Exiguous', 9: 'Mote', 10: 'Fleck', 11: 'Speck', 12: 'Whit', 13: 'Nugatory', 14: 'Titanic', 15: 'Gigantic', 16: 'Gargantuan', 17: 'Colossal', 18: 'Prodigious', 19: 'Humongous', 20: 'Behemoth', 21: 'Mammoth', 22: 'Leviathan', 23: 'Scads', 24: 'Slew', 25: 'Repletion', 26: 'Profusion', 27: 'Preponderance', 28: 'Copiousness', 29: 'Cornucopia', 30: 'Myriad', 31: 'Panoply', 32: 'Oodles', 33: 'Umpteen', 34: 'Plethora', 35: 'Glut', 36: 'Surplus', 37: 'Surfeit', 38: 'Inundation', 39: 'Deluge', 40: 'Superfluity', 41: 'Torrent', 42: 'Apex', 43: 'Acme', 44: 'Consummation', 45: 'Summit', 46: 'Culmination', 47: 'Pinnacle', 48: 'Zenith', 49: 'Apogee', 50: 'Nadir', 51: 'Nether', 52: 'Abyss', 53: 'Abysmal', 54: 'Aggrandize', 55: 'Augment', 56: 'Accentuate', 57: 'Amass', 58: 'Ameliorate', 59: 'Bolster', 60: 'Buttress', 61: 'Burgeon', 62: 'Distend', 63: 'Wax', 64: 'Thrive', 65: 'Attenuate', 66: 'Extenuate', 67: 'Abate', 68: 'Droop', 69: 'Dwindle', 70: 'Flag', 71: 'Ebb', 72: 'Wane', 73: 'Relent', 74: 'Recede', 75: 'Taper', 76: 'Pall', 77: 'Subside', 78: 'Expedite', 79: 'Precipitate', 80: 'Plummet', 81: 'Relegate'}, '50 shades of joy': {0: 'Gay', 1: 'Gleeful', 2: 'Elated', 3: 'Exult', 4: 'Exalt', 5: 'Enthralled', 6: 'Ecstatic', 7: 'Euphoria', 8: 'Enrapture', 9: 'Entrance', 10: 'Exhilarated', 11: 'Rhapsodic', 12: 'Jubilant', 13: 'Jovial', 14: 'Jocund', 15: 'Beatific', 16: 'Blissful', 17: 'Halcyon', 18: 'Heyday', 19: 'Ebullient', 20: 'Exuberant', 21: 'Effervescent', 22: 'Gusty', 23: 'Zesty', 24: 'Feisty', 25: 'Perky', 26: 'Sprightly', 27: 'Vivacious', 28: 'Jaunty', 29: 'Gung-ho', 30: 'animated', 31: 'Rambunctious', 32: 'Rowdy', 33: 'Sally', 34: 'Repartee', 35: 'Retort', 36: 'Rejoinder', 37: 'Quip', 38: 'Banter', 39: 'Badinage', 40: 'Risible', 41: 'Buffoonish', 42: 'Waggish', 43: 'Gaggish', 44: 'Wacky', 45: 'Ludicrous', 46: 'Jocose', 47: 'Droll', 48: 'Farcical', 49: 'Facetious', 50: 'preposterous', 51: 'Scoff', 52: 'Deride', 53: 'Jeer', 54: 'Jibe/gibe', 55: 'Scorn', 56: 'Contempt', 57: 'Sardonic', 58: 'Satire', 59: 'Caricature', 60: 'Spoof', 61: 'Parody', 62: 'Travesty', 63: 'Gloat', 64: 'Smirk', 65: 'Simper', 66: 'Giggle', 67: 'Sniggle', 68: 'Chortle', 69: 'Chuckle', 70: 'Cackle', 71: 'Titter', 72: 'Snicker', 73: 'Guffaw', 74: 'Cacchinate', 75: 'Grin'}, 'Criticism n praise': {0: 'Chide', 1: 'Admonish', 2: 'Reproach', 3: 'Reprove', 4: 'Censure', 5: 'Castigate', 6: 'Chastise', 7: 'Excoriate', 8: 'Pillory', 9: 'Pan', 10: 'Savage', 11: 'Inveigh', 12: 'Rave', 13: 'Rant', 14: 'Rail', 15: 'Rebuke', 16: 'Reprimand', 17: 'Wallop', 18: 'Upbraid', 19: 'Berate', 20: 'Vituperate', 21: 'Vilify', 22: 'Vilipend', 23: 'Harangue', 24: 'Lambaste', 25: 'Assault', 26: 'Assail', 27: 'Flay', 28: 'Fulminate', 29: 'Revile', 30: 'Decry', 31: 'Denounce', 32: 'Denigrate', 33: 'Maul', 34: 'Diatribe', 35: 'Tirade', 36: 'Commination', 37: 'Opprobrium', 38: 'Expletives', 39: 'Imprecation', 40: 'Invectives', 41: 'Crass', 42: 'Canard', 43: 'Calumny', 44: 'Libel', 45: 'Traduce', 46: 'Discredit', 47: 'Defame', 48: 'Taint', 49: 'Tarnish', 50: 'Mar', 51: 'Besmirch', 52: 'Sully', 53: 'Slander', 54: 'Smudge', 55: 'Smear', 56: 'Aspersion', 57: 'Accolades', 58: 'Acclaim', 59: 'Adulation', 60: 'Plaudits', 61: 'Kudos', 62: 'Encomium', 63: 'Eulogy', 64: 'Panegyric', 65: 'Exalt', 66: 'Extol', 67: 'Commendation', 68: 'Felicitation', 69: 'Approbation', 70: 'Citation', 71: 'Paean', 72: 'Ode'}, 'Crime n punishment': {0: 'Gaffe', 1: 'Infraction', 2: 'misdemeanor', 3: 'Peccadilo', 4: 'Venial', 5: 'Indiscretion', 6: 'Felony-opposite', 7: 'Larceny', 8: 'Filch', 9: 'Venal', 10: 'Cache', 11: 'Embezzlement', 12: 'Misappropriate', 13: 'Appropriate', 14: 'Squatter', 15: 'Usurp', 16: 'Pillage', 17: 'Cow', 18: 'Browbeat', 19: 'Impale', 20: 'Ambush', 21: 'Waylay', 22: 'Skulk', 23: 'Lurk', 24: 'Voyeur', 25: 'Pry', 26: 'Eavesdrop', 27: 'Espionage', 28: 'Perpetrator', 29: 'Abscond', 30: 'Circumvent', 31: 'Abettor', 32: 'Accomplice', 33: 'Accessory', 34: 'Collusion', 35: 'Cabal', 36: 'Mutilate', 37: 'Behead', 38: 'Decapitate', 39: 'Gullotine', 40: 'Slash', 41: 'Mangle', 42: 'Lacerate', 43: 'Gruesome', 44: 'Grisly', 45: 'Heinous', 46: 'Ghastly', 47: 'Flagitious', 48: 'Atrocious', 49: 'Horrendous', 50: 'Onslaught', 51: 'Caveat', 52: 'Ordeal', 53: 'Incarcerate', 54: 'Immure', 55: 'Absolve', 56: 'Acquit', 57: 'Exonerate', 58: 'Exculpate', 59: 'Vindicate', 60: 'Amnesty', 61: 'Pardon', 62: 'Clemency', 63: 'Reprieve', 64: 'Respite', 65: 'Remission', 66: 'Comeuppance', 67: 'Retribution', 68: 'Impunity', 69: 'Incorrigible', 70: 'Recidivism', 71: 'Redress'}, 'War n peace': {0: 'Schism', 1: 'Secession', 2: 'Discord', 3: 'Dissent', 4: 'Faction', 5: 'Cleft', 6: 'Dissident', 7: 'Sedition', 8: 'Instigation', 9: 'Insurgency', 10: 'Insurrection', 11: 'Wrangle', 12: 'Row', 13: 'Fray', 14: 'Skirmish', 15: 'Duel', 16: 'Ruckus', 17: 'Rumpus', 18: 'Fracas', 19: 'Brohuhaha', 20: 'Clamor', 21: 'Hubbub', 22: 'Pandemonium', 23: 'Turmoil', 24: 'Tumult', 25: 'Din', 26: 'Melee', 27: 'Malestorm', 28: 'Mayhem', 29: 'Hustle', 30: 'Imbroglio', 31: 'Cauldron', 32: 'Pell-mell', 33: 'Bedlam', 34: 'Pug/bell- fight ', 35: 'Pugnacious', 36: 'Bellicose', 37: 'Belligerent', 38: 'Fiesty', 39: 'Truculent', 40: 'Jingo', 41: 'Pugilist', 42: 'Repugnant', 43: 'Fortitude', 44: 'Spunky', 45: 'Plucky', 46: 'gritty', 47: 'Chivalry', 48: 'Gamely', 49: 'Mettle', 50: 'Valor', 51: 'Valliant (adj)', 52: 'Intrepid', 53: 'Dauntless', 54: 'Gallantry', 55: 'Prowess', 56: 'Audacity', 57: 'Chutzpah', 58: 'Foolhardy', 59: 'Bravado', 60: 'Forbearence', 61: 'Tenacity', 62: 'Resolve', 63: 'Resilience', 64: 'Pusillanimous', 65: 'Dastardly', 66: 'Craven', 67: 'Timorous', 68: 'Spineless', 69: 'Poltroonish', 70: 'Impuissant', 71: 'Restitution', 72: 'Reparation', 73: 'Subjugate', 74: 'Subvert', 75: 'Subdue', 76: 'Foray', 77: 'Rout', 78: 'Vanquish', 79: 'Bastion', 80: 'Bulwark', 81: 'Citadel', 82: 'Fortification', 83: 'Pushover', 84: 'Nemesis', 85: 'Vendatta', 86: 'Vindictive', 87: 'Reprisal'}, 'Anger kills': {0: 'Ire', 1: 'Outrage', 2: 'Umbrage', 3: 'Livid', 4: 'Indignation', 5: 'Wrath', 6: 'Irk', 7: 'Peeve', 8: 'Pique', 9: 'Rasp', 10: 'Grouch', 11: 'Grouse', 12: 'Grump', 13: 'Vex', 14: 'Exasperate', 15: 'Rile', 16: 'Chafe', 17: 'Gall', 18: 'Nettle', 19: 'miffed', 20: 'badger', 21: 'harry', 22: 'dog', 23: 'bug', 24: 'pester', 25: 'Sangfroid', 26: 'equanimity', 27: 'equability', 28: 'Equipoise', 29: 'Repose', 30: 'Ablomb', 31: 'Self-possession', 32: 'Placidity', 33: 'Mercurial', 34: 'Whimsical', 35: 'Fickle-minded', 36: 'Skittish', 37: 'Labile', 38: 'Surly', 39: 'Peevish', 40: 'Petulant', 41: 'Grouchy', 42: 'Grumpy', 43: 'Bilious', 44: 'Splenetic', 45: 'Fractious', 46: 'Curmudgeon', 47: 'Churlish', 48: 'Cantankerous', 49: 'Crotchety', 50: 'Choleric', 51: 'Irascible', 52: 'Spar/Spat', 53: 'Tiff', 54: 'Squabble', 55: 'Quibble', 56: 'Carp', 57: 'Cavil', 58: 'Nag-niggle', 59: 'Whine', 60: 'Repine', 61: 'Seethe', 62: 'Simmer', 63: 'Smolder', 64: 'Frown', 65: 'Glare', 66: 'Glower', 67: 'Scowl', 68: 'Flinch', 69: 'Cower', 70: 'Cringe', 71: 'Assuage', 72: 'Allevaite', 73: 'Allay', 74: 'Placate', 75: 'Pacify', 76: 'Palliate', 77: 'Lull', 78: 'Mitigate', 79: 'Mollify', 80: 'Concillate', 81: 'Propitiate', 82: 'Appease', 83: 'Catharsis'}, 'LSD -1': {0: 'Comely', 1: 'Winsome + some', 2: 'Pulchritude + tude', 3: 'Cherubic', 4: 'Sensual', 5: 'Sultry', 6: 'Nubile', 7: 'Luscious + ous', 8: 'Luxurious', 9: 'Raunchy', 10: 'Bodacious', 11: 'Voluptuous', 12: 'Siren', 13: 'Gargoyle', 14: 'Grotesque', 15: 'Ogle', 16: 'Gawk', 17: 'Amor-love', 18: 'Enamour', 19: 'Amorous', 20: 'Yearn', 21: 'Pine', 22: 'Hanker', 23: 'Yen', 24: 'Wistful', 25: 'Pensive', 26: 'Ulterior', 27: 'Philanderer', 28: 'Coquette', 29: 'siren', 30: 'tantalize + lize', 31: 'titillate', 32: 'alacrity', 33: 'virile', 34: 'effete (opposite)', 35: 'L-series', 36: 'Lecherous', 37: 'Licentious', 38: 'Libertinous', 39: 'Lascivious', 40: 'Libidinous', 41: 'Lustful', 42: 'Lubricious', 43: 'Lewd', 44: 'Wanton', 45: 'Incontinent', 46: 'Prurient', 47: 'Salacious', 48: 'Sleazy', 49: 'Bawdy', 50: 'Escapade', 51: 'Unrequited', 52: 'Camaraderie', 53: 'Amiable', 54: 'Affable', 55: 'Febrile', 56: 'Liaison ', 57: 'tryst', 58: 'privy', 59: 'confidante', 60: 'endearments', 61: 'Misgivings', 62: 'Demur', 63: 'Qualms', 64: 'Scruples', 65: 'Platonic', 66: 'Chaste (c.kiss)', 67: 'Celibate', 68: 'Conjugal', 69: 'Connubial', 70: 'Nuptial', 71: 'Matrimonial', 72: 'Yoke (d.animals)', 73: 'Yoke of woes', 74: 'Consort', 75: 'Doting', 76: 'Uxorious (ug)', 77: 'coddle', 78: 'mollycoddle', 79: 'cosset', 80: 'caress', 81: 'nestle'}, 'LSD-2': {0: 'Fide- faith (root)', 1: 'Infidelity', 2: 'Perfidy', 3: 'Façade', 4: 'Imposter', 5: 'Feign/feint', 6: 'Sham', 7: 'Veneer', 8: 'Dissemblence', 9: 'Affected', 10: 'Mannered', 11: 'Poseur', 12: 'Factitious', 13: 'Paramour', 14: 'Clandestine', 15: 'Discreet', 16: 'Covert', 17: 'Stealthily', 18: 'Furtive', 19: 'Surreptitous', 20: 'Beseech-plead', 21: 'Entreat', 22: 'Implore', 23: 'Supplicate', 24: 'Importune', 25: 'Alienate', 26: 'Estrange', 27: 'Disaffected', 28: 'Sundered', 29: 'Rended', 30: 'Severed', 31: 'Woe', 32: 'woeful', 33: 'woebygone', 34: 'Affliction', 35: 'Anguish', 36: 'Agony', 37: 'Angst', 38: 'Travail', 39: 'Throes', 40: 'Torment', 41: 'Tribulations', 42: 'Excruciation', 43: 'Compunction', 44: 'Rue', 45: 'Penitence', 46: 'Contrition', 47: 'Repentance', 48: 'Remorse', 49: 'Penance', 50: 'Expiation', 51: 'Atonement', 52: 'Lugubrious', 53: 'Plaintive', 54: 'Sombre', 55: 'Melancholy', 56: 'Doleful', 57: 'Despondence', 58: 'Disconsolate', 59: 'Downcast', 60: 'Doldrums', 61: 'Dejected', 62: 'Crestfallen', 63: 'Chapfallen', 64: 'Chagrined', 65: 'Sullen', 66: 'Morose', 67: 'Funereal', 68: 'Mournful', 69: 'Poignant', 70: 'Forlorn', 71: 'Elegy', 72: 'Threnody', 73: 'Dirge', 74: 'Requiem', 75: 'Fulsome', 76: 'Cloying', 77: 'Mawkish', 78: 'Maudlin', 79: 'Effusive', 80: 'Abhorrence', 81: 'Abomination', 82: 'Execration', 83: 'Loathing', 84: 'Despise', 85: 'Repugnance', 86: 'Detestation', 87: 'Aversion', 88: 'Revulsion', 89: 'Resentment', 90: 'Antipathy', 91: 'Spite', 92: 'Jaundice-bitterness/resentment', 93: 'Ill will', 94: 'Enmity', 95: 'Animosity', 96: 'Antagonism', 97: 'Acrimony', 98: 'Pathy/pathos-feeling', 99: 'Sympathy', 100: 'Empathy', 101: 'Pathological', 102: 'Apathy'}, 'Food,clothing n shelter': {0: 'Comestible', 1: 'Palatable', 2: 'Savory', 3: 'Luscious', 4: 'Dainty', 5: 'Ambrosial', 6: 'Insipid (opposite)', 7: 'Abstemious', 8: 'Glutton', 9: 'Indulgent', 10: 'Gourmand', 11: 'Voracious', 12: 'Hog', 13: 'Gourmet', 14: 'Connoisseur', 15: 'Voluptuary', 16: 'Epicure', 17: 'Slake', 18: 'Satiate', 19: 'Imbibe', 20: 'Guzzle', 21: 'Swill', 22: 'Quaff', 23: 'Bacchanalia', 24: 'Orgy', 25: 'carousal', 26: 'Revelry', 27: 'Jamboree', 28: 'Flamboyant', 29: 'Resplendent', 30: 'Refulgent', 31: 'Ostentatious', 32: 'Gaudy', 33: 'Garish', 34: 'Tawdry', 35: 'meretricious', 36: 'Lurid', 37: 'Gossamer', 38: 'Diaphonous', 39: 'Natty', 40: 'Nifty', 41: 'chic', 42: 'spruce', 43: 'dapper', 44: 'dandy', 45: 'fop', 46: 'Hag', 47: 'crone', 48: 'dowdy', 49: 'frump', 50: 'Beldam', 51: 'Disheveled', 52: 'unkempt', 53: 'mangy', 54: 'Dilapidated', 55: 'Derelict', 56: 'in shambles', 57: 'ramshackle', 58: 'rickety', 59: 'Refurbish', 60: 'shipshape', 61: 'Edifice'}, 'Break n brake': {0: 'Spasmodic', 1: 'Sporadic', 2: 'Fitful', 3: 'Erratic', 4: 'Intermittent', 5: 'Forestall', 6: 'preempt', 7: 'preclude', 8: 'Nip in the bud', 9: 'Obviate (single)?', 10: 'Impair', 11: 'Impede', 12: 'Encumber', 13: 'Thwart', 14: 'Foil', 15: 'Frustrate', 16: 'Fetter', 17: 'Pinion', 18: 'Shackle', 19: 'Manacle', 20: 'Balk', 21: 'Stymie', 22: 'Scupper', 23: 'Scuttle', 24: 'Stifle', 25: 'Obstruct', 26: 'Obstacle', 27: 'Check', 28: 'Jeopardize', 29: 'Imperil', 30: 'Hobble', 31: 'Latitude', 32: 'Leeway', 33: 'Impasse', 34: 'Logjam', 35: 'Checkmate', 36: 'Dormancy', 37: 'Quagmire', 38: 'Predicament', 39: 'Lull', 40: 'Limbo', 41: 'Abeyance', 42: 'Doldrums', 43: 'Latency', 44: 'Lacuna', 45: 'Hibernation', 46: 'Quiescence', 47: 'Interregnum', 48: 'Sabbatical', 49: 'Hiatus', 50: 'Moratorium', 51: 'Scotch', 52: 'Nix', 53: 'Vitiate', 54: 'Annul', 55: 'Nullify', 56: 'Zilch', 57: 'Nugatory', 58: 'Quash', 59: 'Rescind', 60: 'Abrogate', 61: 'Repeal', 62: 'Quell', 63: 'Abjure', 64: 'Countermand', 65: 'Retract', 66: 'Recant', 67: 'Abdicate', 68: 'Abnegate', 69: 'Veto', 70: 'Incessant'}, 'A Walk through clouds': {0: 'Balmy', 1: 'Clement', 2: 'Amble-walk (root)', 3: 'Ramble', 4: 'Saunter', 5: 'Promenade', 6: 'Wander', 7: 'Perambulate', 8: 'Stroll', 9: 'Roam', 10: 'Ambulatory', 11: 'Somnambulist', 12: 'Shamble', 13: 'Sultry', 14: 'Muggy', 15: 'Torrid', 16: 'Sere', 17: 'Parch', 18: 'Sear', 19: 'Berserk', 20: 'Go off the rails', 21: 'Frantic', 22: 'Amok', 23: 'Trample', 24: 'Salubrious', 25: 'Salutary', 26: 'Hurtle', 27: 'Dart', 28: 'Career', 29: 'Careen', 30: 'Gait', 31: 'Lope-run (root)', 32: 'Gallop', 33: 'Elope', 34: 'Hobble', 35: 'Falter', 36: 'Totter', 37: 'Stagger', 38: 'Dodder', 39: 'Flounder', 40: 'Dawdle', 41: 'Dilly-dally', 42: 'Loiter', 43: 'Lounge', 44: 'Linger', 45: 'Tarry', 46: 'Loll', 47: 'Hover', 48: 'Genial', 49: 'Milieu', 50: 'Miasma', 51: 'Musty', 52: 'Rancid', 53: 'Putrid', 54: 'Fetid', 55: 'Reek', 56: 'Stench', 57: 'Pestilence', 58: 'Noisome', 59: 'Obnoxious', 60: 'Repugnant', 61: 'Gale', 62: 'Gust', 63: 'Bluster', 64: 'Tempest', 65: 'Tempestuous', 66: 'Thaw'}, 'Time flies': {0: 'Vicissitude', 1: 'Vagary', 2: 'Pastoral', 3: 'Bucolic', 4: 'Rustic', 5: 'Idyllic', 6: 'Picturesque ', 7: 'Quaint', 8: 'Hinterland', 9: 'Pristine', 10: 'Unadulterated', 11: 'Yore', 12: 'Eon', 13: 'Epoch', 14: 'Zeitgeist', 15: 'Passe', 16: 'Archaic', 17: 'Antiquated', 18: 'Antediluvian', 19: 'Superannuated', 20: 'Obsolete', 21: 'Outmoded', 22: 'Vintage', 23: 'Anachronistic', 24: 'Staid', 25: 'Relic', 26: 'Remanants', 27: 'Reminiscence', 28: 'Cliched', 29: 'Platitude', 30: 'Bromide', 31: 'Heckneyed', 32: 'Banal', 33: 'Prosaic', 34: 'Humdrum', 35: 'Ennui', 36: 'Vapid', 37: 'Trite', 38: 'Threadbare', 39: 'Jejune', 40: 'Jaded', 41: 'Hoary', 42: 'Anodyne', 43: 'Blasé', 44: 'Adamant', 45: 'Obdurate', 46: 'Obstinate', 47: 'Recalcitrant', 48: 'Refractory', 49: 'Willful', 50: 'Wayward', 51: 'Contumacious', 52: 'Intransigent', 53: 'Intractable', 54: 'Headstrong', 55: 'Nov-new', 56: 'Neo-new', 57: 'Novice', 58: 'Neologism', 59: 'Noveau Riche', 60: 'Novel', 61: 'Ingenious', 62: 'Unprecedented', 63: 'Trailblazing', 64: 'Pathbreaking', 65: 'Harbinger', 66: 'Herald', 67: 'Precurser', 68: 'Vanguard', 69: 'Coeval'}};

# %%
print(p.keys())
# Out:
# dict_keys(['Birth n death', 'Body n disease-1', 'Body n disease-2', 'Beautiful mind-1', 'Beautiful mind-2', 'Shabd -1', 'Shabd -2', 'Religion', 'Rajneeti -1', 'Rajneeti-2', 'Office office-1', 'Office office-2', 'Money matters', 'Size matters', '50 shades of joy', 'Criticism n praise', 'Crime n punishment', 'War n peace', 'Anger kills', 'LSD -1', 'LSD-2', 'Food,clothing n shelter', 'Break n brake', 'A Walk through clouds', 'Time flies'])

# %%
print(p)
# Out:
# {'Birth n death': {0: 'Primordial', 1: 'Genesis', 2: 'Procreate', 3: 'Spawn', 4: 'Engender', 5: 'Beget', 6: 'Prolific - 1', 7: 'Fecund -2', 8: 'Progeny', 9: 'Lineage', 10: 'Pedigree', 11: 'Kindred', 12: 'Genealogy', 13: 'Generic', 14: 'Genocide', 15: 'Viv-Life', 16: 'Vivify', 17: 'Vivacious', 18: 'Vivisection', 19: 'Nascent', 20: 'Embryonic', 21: 'Germinal', 22: 'Rudimentary', 23: 'Inchoate', 24: 'Incipient', 25: 'Precocious - 1', 26: 'Prodigy -2', 27: 'Ephemeral', 28: 'Evanescent', 29: 'Deciduous', 30: 'Fugitive', 31: 'Transient', 32: 'Temporal', 33: 'Fleeting', 34: 'Morph- form', 35: 'Metamorphosis', 36: 'Amorphous', 37: 'Morphology', 38: 'Mor/mort/necr-death', 39: 'Mortify', 40: 'Moribund', 41: 'Morbid', 42: 'Morose', 43: 'Mortician', 44: 'Inter', 45: 'Exhume (opposite)', 46: 'Sepulcher', 47: 'Necropolis', 48: 'Wraith', 49: 'Spectre', 50: 'Apparition', 51: 'Necromancy', 52: 'Clairvoyance', 53: 'Exorcise', 54: 'Moratorium', 55: 'Annihilate', 56: 'Raze', 57: 'Obliterate', 58: 'Exter
# ...

# %%
for key, value in p.items() :
    print  (key)
# Out:
# Birth n death
# Body n disease-1
# Body n disease-2
# Beautiful mind-1
# Beautiful mind-2
# Shabd -1
# Shabd -2
# Religion
# Rajneeti -1
# Rajneeti-2
# Office office-1
# Office office-2
# Money matters
# Size matters
# 50 shades of joy
# Criticism n praise
# Crime n punishment
# War n peace
# Anger kills
# LSD -1
# LSD-2
# Food,clothing n shelter
# Break n brake
# A Walk through clouds
# Time flies

# %%
dfs=pd.DataFrame.from_dict(p)

# %%
from sqlalchemy import create_engine
database_username = 'root'
database_password = ''
database_ip       = 'localhost'
database_name     = 'vocab'
database_connection = create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name))
dfs.to_sql('vocab1', con=database_connection, if_exists='replace',chunksize=1000,index=False)
